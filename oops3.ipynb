# %%
class human_face:
    def __init__(self,human_face_segment,img):
        self.human_face_segment=human_face_segment
        self.img=img
    def face_segment(self):
        loaded_model=load_model("face_segment.h5")
        prediction=loaded_model.predict(img)
        plt.imshow(prediction)
        plt.show
